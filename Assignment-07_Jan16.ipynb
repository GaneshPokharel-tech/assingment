# %% [markdown]
# ### **Coding Assignment: Data Exploration and Visualization Using Pandas**
#
# ### **Dataset 01:**
# Use the [Iris Species dataset](https://www.kaggle.com/uciml/iris) from Kaggle, which contains measurements of different species of iris flowers.

# %% [markdown]
# #### **Instructions:**
#
# 1. **Importing the Dataset:**
#    - Load the dataset into a pandas DataFrame.
#    - Display the first 5 rows of the dataset.

# %%
import pandas as pd
df = pd.read_csv("/Users/ganeshpokharel/Desktop/datascience/practice_hall/iris.csv")
df.rename(columns={
    "SepalLengthCm": "sepal_length",
    "SepalWidthCm": "sepal_width",
    "PetalLengthCm": "petal_length",
    "PetalWidthCm": "petal_width",
    "Species": "species"
}, inplace=True)

df.head()
# Out:
#    Id  sepal_length  sepal_width  petal_length  petal_width      species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# 2. **Basic Data Exploration:**
#    - **Data Summary:**
#      - Display basic information about the dataset, including the number of rows and columns, data types of each column, and memory usage.
#      - Generate descriptive statistics for the numerical columns (e.g., mean, median, standard deviation).
#    - **Check for Missing Values:**
#      - Identify any missing values in the dataset and explain how you would handle them if there were any.
#    - **Value Counts:**
#      - Display the count of each unique species in the `species` column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe().T
# Out:
#               count       mean        std  min    25%    50%     75%    max
# Id            150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# sepal_length  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# sepal_width   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# petal_length  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# petal_width   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df.isnull().sum()
# Out:
# Id              0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 3. **Filtering and Sorting:**
#    - Filter the dataset to show only the rows where the `sepal_length` is greater than 5.0.
#    - Sort the filtered dataset by `petal_length` in descending order.

# %%
df.columns
# Out:
# Index(['Id', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
filter_df = df[df["sepal_length"] > 5.0]
filter_df
# Out:
#       Id  sepal_length  sepal_width  petal_length  petal_width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 5      6           5.4          3.9           1.7          0.4     Iris-setosa
# 10    11           5.4          3.7           1.5          0.2     Iris-setosa
# 14    15           5.8          4.0           1.2          0.2     Iris-setosa
# 15    16           5.7          4.4           1.5          0.4     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [118 rows x 6 columns]

# %%
short_filter_df = filter_df.sort_values(by="petal_length",ascending=False)
short_filter_df
# Out:
#       Id  sepal_length  sepal_width  petal_length  petal_width         species
# 118  119           7.7          2.6           6.9          2.3  Iris-virginica
# 117  118           7.7          3.8           6.7          2.2  Iris-virginica
# 122  123           7.7          2.8           6.7          2.0  Iris-virginica
# 105  106           7.6          3.0           6.6          2.1  Iris-virginica
# 131  132           7.9          3.8           6.4          2.0  Iris-virginica
# ..   ...           ...          ...           ...          ...             ...
# 28    29           5.2          3.4           1.4          0.2     Iris-setosa
# 33    34           5.5          4.2           1.4          0.2     Iris-setosa
# 16    17           5.4          3.9           1.3          0.4     Iris-setosa
# 36    37           5.5          3.5           1.3          0.2     Iris-setosa
# 14    15           5.8          4.0           1.2          0.2     Iris-setosa
#
# [118 rows x 6 columns]

# %% [markdown]
# 5. **Creating New Columns:**
#    - Create a new column called `sepal_petal_ratio` which is the ratio of `sepal_length` to `petal_length`.

# %%
df["sepal_petal_ratio"] = df["sepal_length"]/df["petal_length"]
df.head()
# Out:
#    Id  sepal_length  sepal_width  petal_length  petal_width      species  \
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_petal_ratio
# 0           3.642857
# 1           3.500000
# 2           3.615385
# 3           3.066667
# 4           3.571429

# %% [markdown]
# 6. **Data Visualization:**
#    - **Histogram:**
#      - Create a histogram to visualize the distribution of `sepal_length` values.
#    - **Scatter Plot:**
#      - Create a scatter plot with `sepal_length` on the x-axis and `petal_length` on the y-axis. Use different colors to represent different species.
#    - **Box Plot:**
#      - Create a box plot for the `sepal_width` values, grouped by `species`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid", palette="pastel")
plt.figure(figsize=(8,5))
plt.hist(df["sepal_length"], bins=15, color="skyblue", edgecolor="black")
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **This histogram shows the distribution of sepal length, where most of the values are concentrated between 5 and 6.5 cm.**

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="sepal_length", y="petal_length", hue="species", palette="Set1", s=100)
plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.show()

# %% [markdown]
# **This scatter plot shows a clear positive relationship between sepal length and petal length, with different species forming distinct clusters.**

# %%
sns.boxplot(
    data=df,
    x="species",
    y="sepal_width",
    hue="species",
    palette="Pastel1",
    legend=False
)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# **This box plot shows that Iris-setosa has the highest median sepal width, Iris-versicolor has the lowest, and Iris-virginica lies in between, with some visible outliers.**

# %% [markdown]
# 7. **Correlation Matrix**
#    - Calculate the correlation matrix for the numerical features and create a heatmap to visualize the correlations using `seaborn`.

# %%
num_df = df.select_dtypes(include="number")

# %%
corr_matrix = num_df.corr()
corr_matrix
# Out:
#                          Id  sepal_length  sepal_width  petal_length  \
# Id                 1.000000      0.716676    -0.397729      0.882747
# sepal_length       0.716676      1.000000    -0.109369      0.871754
# sepal_width       -0.397729     -0.109369     1.000000     -0.420516
# petal_length       0.882747      0.871754    -0.420516      1.000000
# petal_width        0.899759      0.817954    -0.356544      0.962757
# sepal_petal_ratio -0.828586     -0.698962     0.588486     -0.934778
#
#                    petal_width  sepal_petal_ratio
# Id                    0.899759          -0.828586
# sepal_length          0.817954          -0.698962
# sepal_width          -0.356544           0.588486
# petal_length          0.962757          -0.934778
# petal_width           1.000000          -0.896479
# sepal_petal_ratio    -0.896479           1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# **The correlation heatmap visualizes relationships among numerical features. Petal length and petal width show a very strong positive correlation, indicating that they increase together. Sepal length is also positively correlated with petal dimensions. In contrast, sepal petal ratio shows strong negative correlation with petal features, meaning it decreases as petal size increases. Sepal width has weak correlation with most features.**

# %% [markdown]
# ---

# %% [markdown]
# ### **Dataset 02 :** [House Prices Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# The dataset includes 79 explanatory variables that describe aspects of residential homes.
#
# #### **Instructions**:
# - Use Python and Jupyter Notebook to solve the questions.
# - Ensure your code is efficient, well-commented, and follows best practices for handling missing data and outliers.
# - Use appropriate visualizations where needed and include explanations for your analysis.

# %% [markdown]
# ### **Problem 1: Data Exploration with Pandas**
# 1. Load the House Prices dataset using Pandas and perform initial exploration:
#    - Display the first and last 5 rows.
#    - Display the **data types** of each column.
#    - Check for **missing values** and calculate the percentage of missing data for each column.
#    - Summarize the **statistical properties** of the numerical columns using `describe()`.
#
# 2. Based on the dataset, identify the following:
#    - Columns that are **categorical** and **numerical**.
#    - Any potential **outliers** in the numerical columns (use visualizations like boxplots).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house_df = pd.read_csv("/Users/ganeshpokharel/Desktop/datascience/practice_hall/house_train.csv")
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
missing_values = house_df.isnull().sum()
missing_values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missing_percentage = (missing_values/len(house_df))*100
missing_percentage
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
missing_df = pd.DataFrame({
    "Missing Values": missing_values,
    "Percentage": missing_percentage
})

# %%
missing_df[missing_df["Missing Values"] > 0].sort_values(by="Percentage", ascending=False)
# Out:
#               Missing Values  Percentage
# PoolQC                  1453   99.520548
# MiscFeature             1406   96.301370
# Alley                   1369   93.767123
# Fence                   1179   80.753425
# MasVnrType               872   59.726027
# FireplaceQu              690   47.260274
# LotFrontage              259   17.739726
# GarageType                81    5.547945
# GarageYrBlt               81    5.547945
# GarageFinish              81    5.547945
# GarageQual                81    5.547945
# GarageCond                81    5.547945
# BsmtFinType2              38    2.602740
# BsmtExposure              38    2.602740
# BsmtFinType1              37    2.534247
# BsmtCond                  37    2.534247
# BsmtQual                  37    2.534247
# MasVnrArea                 8    0.547945
# Electrical                 1    0.068493

# %%
house_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
categorical_cols = house_df.select_dtypes(include="object").columns
categorical_cols
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
numerical_cols = house_df.select_dtypes(include=["int64", "float64"]).columns
numerical_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
key_col = ["LotArea", "GrLivArea", "TotalBsmtSF", "1stFlrSF", "SalePrice"]

for col in key_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=house_df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ### **Problem 2: Data Manipulation with Pandas**
# 1. Filter the dataset to include only houses where the **SalePrice** is above the **90th percentile**.
# 2. Create a new **calculated column**: `Price_Per_SqFt = SalePrice / GrLivArea`.
# 3. **Group the data** by `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 4. Sort the dataset by `Price_Per_SqFt` and display the **top 10 rows**.

# %%
price_threshold = house_df["SalePrice"].quantile(0.90)
price_threshold
# Out:
# np.float64(278000.0)

# %%
high_value_df = house_df[house_df["SalePrice"] > price_threshold].copy()
high_value_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1403  1404          20       RL         49.0    15256   Pave   NaN      IR1
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
#
# ...

# %%
high_value_df["Price_Per_SqFt"] = high_value_df["SalePrice"] / high_value_df["GrLivArea"]
high_value_df["Price_Per_SqFt"]
# Out:
# 6       181.227863
# 11      148.450947
# 13      187.081660
# 20      136.910774
# 27      179.577465
#            ...
# 1403    193.252732
# 1417    138.775510
# 1437    204.253106
# 1442    154.459392
# 1451    181.932826
# Name: Price_Per_SqFt, Length: 145, dtype: float64

# %%
high_value_df.groupby("Neighborhood")["SalePrice"].agg(["mean", "median"])
# Out:
#                        mean    median
# Neighborhood
# ClearCr       303333.333333  302000.0
# CollgCr       319081.444444  297000.0
# Crawfor       340442.857143  335000.0
# Edwards       320000.000000  320000.0
# Gilbert       348750.000000  348750.0
# NAmes         345000.000000  345000.0
# NWAmes        299800.000000  299800.0
# NoRidge       378367.333333  336000.0
# NridgHt       371608.541667  352000.0
# OldTown       365000.000000  325000.0
# SawyerW       312533.333333  316600.0
# Somerst       324222.230769  311872.0
# StoneBr       405289.583333  384713.0
# Timber        320929.416667  313750.0
# Veenker       334333.333333  324000.0

# %%
high_value_df.sort_values(by="Price_Per_SqFt", ascending=False).head(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 688    689          20       RL         60.0     8089   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1181  1182         120       RM         64.0     5587   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 1243  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 473    474          20       RL        110.0    14977   Pave   NaN      IR1
# 151    152          20       RL        107.0    13891   Pave   NaN      Reg
# 1388  1389          20       RL         42.0    14892   Pave   NaN      IR1
# 1228  1229         120       RL         65.0     8769   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold  \
# ...

# %% [markdown]
# ### **Problem 3: Handling Missing Data and Imputation**
# 1. Identify columns with **missing values**.
# 2. Impute the missing values:
#    - For **numerical columns**, replace missing values with the **median**.
#    - For **categorical columns**, replace missing values with the **most frequent** value.
# 3. Justify your choice of imputation methods and check if any missing data remains.

# %%
missing_data = house_df.isnull().sum()
columns_with_missing = missing_data[missing_data > 0]
columns_with_missing
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
for col in numerical_cols:
    if house_df[col].isnull().sum() > 0:
        median_val = house_df[col].median()
        house_df[col] = house_df[col].fillna(median_val)

# %%
for col in categorical_cols:
        if house_df[col].isnull().sum() > 0:
            mode_val = house_df[col].mode()[0]
        house_df[col] = house_df[col].fillna(mode_val)

# %%
total_missing_after = house_df.isnull().sum().sum()
total_missing_after
# Out:
# np.int64(0)

# %% [markdown]
# ### **Problem 4: Numpy Array Operations**
# 1. Convert the numerical columns (such as `LotArea`, `YearBuilt`, `GrLivArea`, `SalePrice`, etc.) into a **NumPy array**.
# 2. Perform the following NumPy operations on the array:
#    - Compute the **mean** and **standard deviation** of each column.
#    - Normalize the data using **min-max scaling** and **z-score normalization**.
#    - Compute the **dot product** between two numerical columns of your choice.

# %%
import numpy as np

# %%
numerical_columns = ["LotArea", "YearBuilt", "GrLivArea", "SalePrice"]

# %%
house_array = house_df[numerical_features].values

# %%
house_array[:5]
# Out:
# array([[  8450,   2003,   1710, 208500],
#        [  9600,   1976,   1262, 181500],
#        [ 11250,   2001,   1786, 223500],
#        [  9550,   1915,   1717, 140000],
#        [ 14260,   2000,   2198, 250000]])

# %%
column_means = np.mean(house_array, axis=0)
column_std = np.std(house_array, axis=0)
column_std
# Out:
# array([9.97784611e+03, 3.01925588e+01, 5.25300394e+02, 7.94152919e+04])

# %%
min_vals = np.min(house_array, axis=0)
max_vals = np.max(house_array, axis=0)
min_max_scaled = (house_array - min_vals) / (max_vals - min_vals)

z_score_normalized = (house_array - column_means) / column_std
min_max_scaled[:2]
# Out:
# array([[0.0334198 , 0.94927536, 0.25923135, 0.24107763],
#        [0.03879502, 0.75362319, 0.17483044, 0.20358284]])

# %%
gr_liv_area = house_array[:, 2] 
sale_price = house_array[:, 3]  

dot_product = np.dot(gr_liv_area, sale_price)

dot_product
# Out:
# np.int64(443462020418)

# %% [markdown]
# ### **Problem 5: Data Visualization**
# Using Matplotlib and/or Seaborn, visualize the following:
# 1. **Distribution** of `SalePrice` using a **histogram**.
# 2. **Box plot** of `SalePrice` grouped by `OverallQual` (overall quality of the house).
# 3. **Scatter plot** between `GrLivArea` (Above-ground living area) and `SalePrice`. Analyze the relationship.
# 4. Plot a **correlation heatmap** for the numerical columns.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(house_df["SalePrice"], kde=True, color="blue")

plt.title("Distribution of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **The SalePrice data shows that the market is mostly centered around mid-range prices, but the right-side skew indicates a few luxury homes are pulling the average up.**

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x="OverallQual", y="SalePrice", data=house_df, palette="viridis")

plt.title("SalePrice vs Overall Quality")
plt.xlabel("Overall Quality (1-10)")
plt.ylabel("SalePrice")
plt.show()
# Out:
# /var/folders/bt/pcxs82x914b3zh57lplprzg80000gn/T/ipykernel_28551/1292458659.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="OverallQual", y="SalePrice", data=house_df, palette="viridis")

# %% [markdown]
# **The box plot clearly demonstrates a positive correlation between "Overall Quality" and "SalePrice". We can see that as the house quality improves from 1 to 10, the median price consistently rises.**

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x="GrLivArea", y="SalePrice", data=house_df, alpha=0.5)

plt.title("GrLivArea vs SalePrice")
plt.xlabel("Above Ground Living Area (SqFt)")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# **The scatter plot reveals a strong positive correlation between the Above Ground Living Area (GrLivArea) and the SalePrice. As the square footage of a house increases, its price generally tends to rise as well. However, we can also spot a few outliers where very large houses are sold for relatively low prices.**

# %%
numerical_columns = house_df.select_dtypes(include=["int64", "float64"]).columns
corr_matrix = house_df[numerical_columns].corr()

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", linewidths=0.5)

plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# **This heatmap shows how house features are related to the house price.
# Features like OverallQual, GrLivArea, TotalBsmtSF, and GarageCars have a strong relationship with SalePrice, which means bigger and better houses usually cost more.
# Some features like PoolArea and MiscVal have little effect on the price.**

# %% [markdown]
# ### **Problem 6: Aggregation and Transformation**
# 1. Perform a **groupby** operation on `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 2. Use the `apply()` function to create a custom transformation for `SalePrice` (e.g., scaling or transformation).
# 3. Aggregate multiple statistical values (e.g., **mean**, **median**, and **count**) for `SalePrice` grouped by `OverallQual`.

# %%
neighborhood_stats = house_df.groupby("Neighborhood")["SalePrice"].agg(["mean", "median"])
neighborhood_stats.head()
# Out:
#                        mean    median
# Neighborhood
# Blmngtn       194870.882353  191000.0
# Blueste       137500.000000  137500.0
# BrDale        104493.750000  106000.0
# BrkSide       124834.051724  124300.0
# ClearCr       212565.428571  200250.0

# %%
def scale_to_thousands(price):
    return price / 1000
    
house_df["SalePrice_K"] = house_df["SalePrice"].apply(scale_to_thousands)
house_df[["SalePrice", "SalePrice_K"]].head()
# Out:
#    SalePrice  SalePrice_K
# 0     208500        208.5
# 1     181500        181.5
# 2     223500        223.5
# 3     140000        140.0
# 4     250000        250.0

# %%
quality_stats = house_df.groupby("OverallQual")["SalePrice"].agg(["mean", "median", "count"])
quality_stats
# Out:
#                       mean    median  count
# OverallQual
# 1             50150.000000   50150.0      2
# 2             51770.333333   60000.0      3
# 3             87473.750000   86250.0     20
# 4            108420.655172  108000.0    116
# 5            133523.347607  133000.0    397
# 6            161603.034759  160000.0    374
# 7            207716.423197  200141.0    319
# 8            274735.535714  269750.0    168
# 9            367513.023256  345000.0     43
# 10           438588.388889  432390.0     18
